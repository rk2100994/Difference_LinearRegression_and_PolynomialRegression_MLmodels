# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# Importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
# dataset.head()
# X = dataset.iloc[:, 1].values, this could be taken as vector, but it should consider it as matrix
X = dataset.iloc[:,1:2].values
y = dataset.iloc[:, 2].values

# %%
#Fitting Linear Regression
linear_regressor = LinearRegression()
linear_regressor.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Fitting Polynomial Linear Regression
# poly_regressor = PolynomialFeatures(degree = 2) for better results degree need to be adjusted
poly_regressor = PolynomialFeatures(degree = 4)
X_poly = poly_regressor.fit_transform(X)
linear_regressor2 = LinearRegression()
linear_regressor2.fit(X_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Visualizing linear regression results
plt.scatter(X,y, color='red')
plt.plot(X,linear_regressor.predict(X), color='blue')
plt.title('Truth or Bluff (Linear Regressor)')
plt.xlabel("Position Level")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Visualizing polynomial linear regression results
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X,y, color='red')
plt.plot(X,linear_regressor2.predict(poly_regressor.fit_transform(X)), color='blue')
plt.title('Truth or Bluff (Linear Regressor)')
plt.xlabel("Position Level")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
